# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("wages_hours.csv", sep = "\t")

# %%
dataframe=pd.DataFrame(dataset)

# %%
dataframe
# Out:
#      HRS   RATE  ERSP ERNO  NEIN  ASSET   AGE    DEP  RACE  SCHOOL
# 0   2157  2.905  1121  291   380   7250  38.5  2.340  32.1    10.5
# 1   2174  2.970  1128  301   398   7744  39.3  2.335  31.2    10.5
# 2   2062  2.350  1214  326   185   3068  40.1  2.851     *     8.9
# 3   2111  2.511  1203   49   117   1632  22.4  1.159  27.5    11.5
# 4   2134  2.791  1013  594   730  12710  57.7  1.229  32.5     8.8
# 5   2185  3.040  1135  287   382   7706  38.6  2.602  31.4    10.7
# 6   2210  3.222  1100  295   474   9338  39.0  2.187  10.1    11.2
# 7   2105  2.493  1180  310   255   4730  39.9  2.616  71.1     9.3
# 8   2267  2.838  1298  252   431   8317  38.9  2.024   9.7    11.1
# 9   2205  2.356   885  264   373   6789  38.8  2.662  25.2     9.5
# 10  2121  2.922  1251  328   312   5907  39.8  2.287  51.1    10.3
# 11  2109  2.499  1207  347   271   5069  39.7  3.193     *     8.9
# 12  2108  2.796  1036  300   259   4614  38.2  2.040     *     9.2
# ...

# %%
maximum = dataframe.max()
maximum
# Out:
# HRS        2267
# RATE      3.636
# ERSP        990
# ERNO        594
# NEIN        730
# ASSET     12710
# AGE        57.7
# DEP       4.512
# RACE        9.7
# SCHOOL     11.7
# dtype: object

# %%
minimum = dataframe.min()
minimum
# Out:
# HRS        1985
# RATE      1.423
# ERSP          *
# ERNO          *
# NEIN         95
# ASSET      1370
# AGE        22.4
# DEP           *
# RACE          *
# SCHOOL      6.6
# dtype: object

# %%
mean_ = dataframe.mean()
mean_
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_3796\3650714485.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_ = dataframe.mean()
# HRS       2137.384615
# RATE         2.772231
# NEIN       331.641026
# ASSET     6265.256410
# AGE         39.351282
# SCHOOL       9.997436
# dtype: float64

# %%
maximum.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 maximum.plot()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:327, in MPLPlot.generate(self)
#     325 def generate(self):
# ...
