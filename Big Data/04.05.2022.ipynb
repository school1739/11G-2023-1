# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
hubble_data = pd.read_csv("hubble_data.csv")
hubble_data
# Out:
#     distance  recession_velocity
# 0      0.032                 170
# 1      0.034                 290
# 2      0.214                -130
# 3      0.263                 -70
# 4      0.275                -185
# 5      0.275                -220
# 6      0.450                 200
# 7      0.500                 290
# 8      0.500                 270
# 9      0.630                 200
# 10     0.800                 300
# 11     0.900                 -30
# 12     0.900                 650
# 13     0.900                 150
# 14     0.900                 500
# 15     1.000                 920
# 16     1.100                 450
# 17     1.100                 500
# 18     1.400                 500
# 19     1.700                 960
# 20     2.000                 500
# 21     2.000                 850
# 22     2.000                 800
# 23     2.000                1090

# %%
wages_hours_data = pd.read_csv("wages_hours.csv", sep="\t")
wages_hours_data2= pd.read_csv("wages_hours2.csv", sep="\t")
wages_hours_data2
# Out:
#     2157  2.905   1121   291  380   7250  38.5     2.340    32.1  10.5
# 0   2174  2.970   1128   301  398   7744  39.3     2.335    31.2  10.5
# 1   2062  2.350   1214   326  185   3068  40.1     2.851  1200.0   8.9
# 2   2111  2.511   1203    49  117   1632  22.4     1.159    27.5  11.5
# 3   2134  2.791  1z013   594  730  12710  57.7     1.229    32.5   8.8
# 4   2185  3.040   1135   287  382   7706  38.6     2.602    31.4  10.7
# 5   2210  3.222   1100   295  474   9338  39.0     2.187    10.1  11.2
# 6   2105  2.493   1180   310  255   4730  39.9     2.616    71.1   9.3
# 7   2267  2.838   1298   252  431   8317  38.9     2.024     9.7  11.1
# 8   2205  2.356    885   264  373   6789  38.8     2.662    25.2   9.5
# 9   2121  2.922   1251   328  312   5907  39.8     2.287    51.1  10.3
# 10  2109  2.499   1207   347  271   5069  39.7     3.193  1000.0   8.9
# 11  2108  2.796   1036   300  259   4614  38.2     2.040  1000.0   9.2
# ...

# %%
maximum = hubble_data.max()
maximum
# Out:
# distance                 2.0
# recession_velocity    1090.0
# dtype: float64

# %%
hubble_frame = pd.DataFrame({"Max": maximum,"Min":hubble_data.min(),"Avg":hubble_data.mean()})
hubble_frame
# Out:
#                        Max      Min         Avg
# distance               2.0    0.032    0.911375
# recession_velocity  1090.0 -220.000  373.125000

# %%
wages_hours_frame = pd.DataFrame({"Max": wages_hours_data2.max(),"Min":wages_hours_data2.min(),"Avg":wages_hours_data2.mean()})
wages_hours_frame
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_1284\3980942259.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   wages_hours_frame = pd.DataFrame({"Max": wages_hours_data2.max(),"Min":wages_hours_data2.min(),"Avg":wages_hours_data2.mean()})
#           Max    Min          Avg
# 10.5     11.7    6.6     9.984211
# 1121      990   1000          NaN
# 2.340  1000.0  1.159    54.982342
# 2.905   3.636  1.423     2.768737
# 2157     2267   1985  2136.868421
# 291      1000     30   353.868421
# 32.1   1200.0    9.7   245.913158
# 38.5     57.7   22.4    39.373684
# 380       730     95   330.368421
# 7250    12710   1370  6239.342105

# %%
hubble_data.plot(x ="distance", y ="recession_velocity" )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
wages_hours_data.plot(x1 ="HRS", x2 = "RATE" )
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 wages_hours_data.plot(x1 ="HRS", x2 = "RATE" )
#       2 plt.show
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...
